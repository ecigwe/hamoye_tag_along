# %% [markdown]
# # Introduction

# %% [markdown]
# ## Data Gathering

# %% [markdown]
# the data set was provided by hamoye. i downloaded from a github link provided by hamoye

# %%
import pandas as pd

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')

# %%
df.head(2)
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
# 1          4  Algeria       2501  Population          5301
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity   1000 tonnes      0.0      0.0      0.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0

# %%
df.sample(2)
# Out:
#        Area Code    Area  Item Code           Item  Element Code  \
# 3915          53   Benin       2763   Pelagic Fish          5301
# 22797         75  Gambia       2960  Fish, Seafood          5072
#
#                         Element         Unit  Y2014  Y2015  Y2016  Y2017  \
# 3915   Domestic supply quantity  1000 tonnes   22.0  25.67  23.72  17.36
# 22797           Stock Variation  1000 tonnes    0.0   0.00   0.00   0.00
#
#        Y2018
# 3915   17.36
# 22797   0.00

# %% [markdown]
# ## Assessment

# %%
# checking the shape of the dataset

# %%
df.shape
# Out:
# (60943, 12)

# %%
# checking for empty rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# creaating a copy of the dataset

# %%
df_clean = df.copy()

# %%
df_clean.head(3)
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
#
#                          Element             Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes     1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity      1000 tonnes      0.0      0.0      0.0
# 2  Food supply (kcal/capita/day)  kcal/capita/day   3377.0   3379.0   3372.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0
# 2   3341.0   3322.0

# %%
df_clean.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df_clean.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df_clean.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [54], in <cell line: 3>()
#       1 my_tuppy = (1,2,5,8)
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
df_clean[['Y2017','Area' ]].groupby('Area').sum().sort_values(by=['Y2017'])
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %%
df_clean.groupby(['Element','Item']).sum()
# Out:
#                                                   Area Code  Item Code  \
# Element                  Item
# Domestic supply quantity Alcohol, Non-Food             6020     119655
#                          Alcoholic Beverages           6020     131580
#                          Animal fats                   6020     132570
#                          Apples and products           6020     117765
#                          Aquatic Animals, Others       5406     110760
# ...                                                     ...        ...
# Tourist consumption      Vegetables                     558      17508
#                          Vegetables, Other              558      15630
#                          Wheat and products             558      15066
#                          Wine                           558      15930
#                          Yams                           327       7605
#
#                                                   Element Code     Y2014  \
# ...

# %%
a = df_clean[df_clean['Item'] == 'Protein']['Y2015']

# %%
[a]
# Out:
# [Series([], Name: Y2015, dtype: float64)]

# %%
df_clean.groupby('Area')['']

# %% [markdown]
# ## Visualizations

# %% [markdown]
# # Findings
